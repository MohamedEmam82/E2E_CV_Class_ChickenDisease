# %%
from ChickenDisease import logger

logger.info(msg="This is a testing message from the logger of Chicken Disease Classification project.")
# Out:
# [2025-08-27 23:57:09,938: INFO: 35202710: This is a testing message from the logger of Chicken Disease Classification project.]

# %%
from ChickenDisease.utils.common_functions import encodeImage
from pathlib import Path

img_path = "bearedman.png"
img_b64 = encodeImage(img_path)
print(img_b64)
type(img_b64)
# Out:
# ...
# str
